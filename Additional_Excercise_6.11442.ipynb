# %%
import pandas as pd

# %%
ratings = pd.read_csv('ratings.csv')

# %%
tags = pd.read_csv('tags.csv')

# %%
movies = pd.read_csv('movies.csv')

# %%
#2

type(tags.iloc[0])
# Out:
# pandas.core.series.Series

# %%
#3

tags.iloc[[0,11,2000]]
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %%
#4

print(tags.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465564 entries, 0 to 465563
# Data columns (total 4 columns):
# userId       465564 non-null int64
# movieId      465564 non-null int64
# tag          465548 non-null object
# timestamp    465564 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 14.2+ MB
# None

# %%
#5

ratings.info()
ratings['rating'].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
# userId       int64
# movieId      int64
# rating       float64
# timestamp    int64
# dtypes: float64(1), int64(3)
# memory usage: 610.4 MB
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
#6

ratings[ratings['rating']> 4]
# Out:
#           userId  movieId  rating   timestamp
# 30             1     1196     4.5  1112484742
# 31             1     1198     4.5  1112484624
# 131            1     4993     5.0  1112484682
# 142            1     5952     5.0  1112484619
# 158            1     7153     5.0  1112484633
# 170            1     8507     5.0  1094786027
# 171            1     8636     4.5  1112485493
# 176            2       62     5.0   974820598
# 177            2       70     5.0   974820691
# 180            2      260     5.0   974821014
# 181            2      266     5.0   974820748
# 183            2      480     5.0   974820720
# 184            2      541     5.0   974821014
# 185            2      589     5.0   974820658
# 188            2      924     5.0   974821014
# 190            2     1196     5.0   974821014
# 191            2     1210     5.0   974820598
# 192            2     1214     5.0   974821014
# 193            2     1249     5.0   974820691
# ...

# %%
#7

ratings.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
#8

movies[movies['genres'].str.contains('Animation')]
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 12          13                                       Balto (1995)
# 47          48                                  Pocahontas (1995)
# 236        239                              Goofy Movie, A (1995)
# 241        244                            Gumby: The Movie (1995)
# 310        313                          Swan Princess, The (1994)
# 360        364                              Lion King, The (1994)
# 388        392         Secret Adventures of Tom Thumb, The (1993)
# 547        551             Nightmare Before Christmas, The (1993)
# 553        558                             Pagemaster, The (1994)
# 582        588                                     Aladdin (1992)
# 588        594             Snow White and the Seven Dwarfs (1937)
# 589        595                        Beauty and the Beast (1991)
# ...

# %%
#9

movies_ratings = pd.merge(movies, ratings, on='movieId', how='inner')
movies_ratings
# Out:
#           movieId                                              title  \
# 0               1                                   Toy Story (1995)
# 1               1                                   Toy Story (1995)
# 2               1                                   Toy Story (1995)
# 3               1                                   Toy Story (1995)
# 4               1                                   Toy Story (1995)
# 5               1                                   Toy Story (1995)
# 6               1                                   Toy Story (1995)
# 7               1                                   Toy Story (1995)
# 8               1                                   Toy Story (1995)
# 9               1                                   Toy Story (1995)
# 10              1                                   Toy Story (1995)
# 11              1                                   Toy Story (1995)
# 12              1                                   Toy Story (1995)
# ...

# %%
movies_ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
#10

movies_tags = pd.merge(movies, tags, on = 'movieId', how = 'inner')

# %%
movies_tags
# Out:
#         movieId                                          title  \
# 0             1                               Toy Story (1995)
# 1             1                               Toy Story (1995)
# 2             1                               Toy Story (1995)
# 3             1                               Toy Story (1995)
# 4             1                               Toy Story (1995)
# 5             1                               Toy Story (1995)
# 6             1                               Toy Story (1995)
# 7             1                               Toy Story (1995)
# 8             1                               Toy Story (1995)
# 9             1                               Toy Story (1995)
# 10            1                               Toy Story (1995)
# 11            1                               Toy Story (1995)
# 12            1                               Toy Story (1995)
# 13            1                               Toy Story (1995)
# ...

# %%
#11

movies_ratings[(movies_ratings['genres'].str.contains('Comedy')) & (movies_ratings['rating'] > 3.0)]
# Out:
#           movieId                                              title  \
# 0               1                                   Toy Story (1995)
# 1               1                                   Toy Story (1995)
# 2               1                                   Toy Story (1995)
# 3               1                                   Toy Story (1995)
# 4               1                                   Toy Story (1995)
# 5               1                                   Toy Story (1995)
# 6               1                                   Toy Story (1995)
# 7               1                                   Toy Story (1995)
# 9               1                                   Toy Story (1995)
# 11              1                                   Toy Story (1995)
# 12              1                                   Toy Story (1995)
# 14              1                                   Toy Story (1995)
# 15              1                                   Toy Story (1995)
# ...

# %%
#12
import numpy as np

pd.DataFrame(movies['genres'].str.split('|', expand=True))
#pd.DataFrame.from_dict(zip(s.index, s.values))
# Out:
#                         0          1         2        3         4     5     6  \
# 0               Adventure  Animation  Children   Comedy   Fantasy  None  None
# 1               Adventure   Children   Fantasy     None      None  None  None
# 2                  Comedy    Romance      None     None      None  None  None
# 3                  Comedy      Drama   Romance     None      None  None  None
# 4                  Comedy       None      None     None      None  None  None
# 5                  Action      Crime  Thriller     None      None  None  None
# 6                  Comedy    Romance      None     None      None  None  None
# 7               Adventure   Children      None     None      None  None  None
# 8                  Action       None      None     None      None  None  None
# 9                  Action  Adventure  Thriller     None      None  None  None
# 10                 Comedy      Drama   Romance     None      None  None  None
# ...

# %%
#13

movies['year'] = movies['title'].str[-6:]

# %%
movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
#14
import datetime

ratings['date'] = pd.to_datetime(ratings['timestamp'],unit='s')

#ratings[ratings['date' > datetime.date(2015, 2, 1)]]
ratings[ratings['date'] > '2015-02-01']
# Out:
#           userId  movieId  rating   timestamp                date
# 3534          31        1     3.0  1424733487 2015-02-23 23:18:07
# 3535          31      110     5.0  1424733473 2015-02-23 23:17:53
# 3536          31      260     5.0  1424733433 2015-02-23 23:17:13
# 3537          31      364     3.0  1424844807 2015-02-25 06:13:27
# 3538          31      527     0.5  1424733598 2015-02-23 23:19:58
# 3539          31      588     3.0  1424842869 2015-02-25 05:41:09
# 3540          31      594     2.5  1424844811 2015-02-25 06:13:31
# 3541          31      616     4.0  1424844817 2015-02-25 06:13:37
# 3542          31     1196     5.0  1424733435 2015-02-23 23:17:15
# 3543          31     1197     3.0  1424734492 2015-02-23 23:34:52
# 3544          31     1207     0.5  1424734478 2015-02-23 23:34:38
# 3545          31     1210     5.0  1424733439 2015-02-23 23:17:19
# 3546          31     1214     0.5  1424733574 2015-02-23 23:19:34
# ...

# %%
#15

tags['date'] = pd.to_datetime(tags['timestamp'],unit='s')
tags.sort_values(by='date')
# Out:
#         userId  movieId                              tag   timestamp  \
# 333932  100371     2788                     monty python  1135429210
# 333927  100371     1732                    coen brothers  1135429236
# 333924  100371     1206                  stanley kubrick  1135429248
# 333923  100371     1193                   jack nicholson  1135429371
# 333939  100371     5004                    peter sellers  1135429399
# 333922  100371       47                   morgan freeman  1135429412
# 333921  100371       47                        brad pitt  1135429412
# 333936  100371     4011                        brad pitt  1135429431
# 333937  100371     4011                      guy ritchie  1135429431
# 333920  100371       32                     bruce willis  1135429442
# 333933  100371     2858                     kevin spacey  1135429466
# 333931  100371     2329                     fuckoff nazi  1135429508
# 333930  100371     2329                    edward norton  1135429508
# ...

# %%
ratings[['rating','userId']].apply(lambda x:x**2)
# Out:
#           rating       userId
# 0          12.25            1
# 1          12.25            1
# 2          12.25            1
# 3          12.25            1
# 4          12.25            1
# 5          12.25            1
# 6          16.00            1
# 7          16.00            1
# 8          16.00            1
# 9          16.00            1
# 10         16.00            1
# 11         16.00            1
# 12         16.00            1
# 13         12.25            1
# 14         12.25            1
# 15         16.00            1
# 16         12.25            1
# 17         12.25            1
# 18          9.00            1
# 19         12.25            1
# 20         12.25            1
# 21         12.25            1
# 22         16.00            1
# 23         16.00            1
# 24         12.25            1
# 25         12.25            1
# 26         16.00            1
# 27         16.00            1
# 28         12.25            1
# 29         12.25            1
# ...
